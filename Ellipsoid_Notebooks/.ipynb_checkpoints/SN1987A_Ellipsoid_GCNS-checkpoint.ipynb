# %% [markdown]
# # SN1987A SETI Ellipsoid with GCNS
#
# Here we explore the SETI Ellipsoid with the the Gaia Catalogue of Nearby Stars (GCNS), which contains stars within our 100 parsec neighborhood.
#
# ### Data
#
# The data table is located at ../../GCNS.fits, and can be obtained via the ```queryGaia.py``` script, as detailed in the ReadMe.

# %% [markdown]
# ### Import Packages

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.colors import LogNorm

from astropy.coordinates import SkyCoord
import astropy.coordinates as coord
from astropy import constants as const
from astropy import units as u
from astropy.time import Time
from astropy.table import Table
from scipy.stats import binned_statistic, binned_statistic_2d

import cubehelix

# %%
import matplotlib
from mpl_toolkits.mplot3d import axes3d   
matplotlib.rcParams.update({'font.size':18})
matplotlib.rcParams.update({'font.family':'serif'})

# %% [markdown]
# #### Color Maps

# %%
CMAP1 = cubehelix.cmap(start=0.5, rot=-0.6, sat=1.8, reverse=True)
CMAP2 = cubehelix.cmap(start=1.5, rot=-0.6, sat=1.8, reverse=True)

# %% [markdown]
# #### Create SkyCoord Object for SN1987A with RA, Dec, Distance

# %%
# Properties of SN1987A
t0 = Time({'year': 1987, 'month': 2, 'day': 23}, format='ymdhms')

c0_radec = SkyCoord.from_name('SN 1987A')

# Panagia (1999) https://ui.adsabs.harvard.edu/abs/1999IAUS..190..549P/abstract
d0 = 51.4 * u.kpc
d0_err = 1.2 * u.kpc

c0 = SkyCoord(ra=c0_radec.ra, dec=c0_radec.dec, distance=d0)

# %%
print(c0_radec)
print(d0.to('pc'))
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.86675, -69.2697417)>
# 51400.0 pc

# %% [markdown]
# #### Read in GCNS Data and Turn Into SkyCoord Objects

# %%
# GCNS data: https://arxiv.org/abs/2012.02061
GCNS_file = '../../GCNS.fits'
GCNS = Table.read(GCNS_file, format='fits')

# %%
c1 = SkyCoord(ra = GCNS['ra'],
              dec = GCNS['dec'],
              distance = GCNS['dist'],
              frame = 'icrs')

# %%
c1[0]
# Out:
# <SkyCoord (ICRS): (ra, dec, distance) in (deg, deg, kpc)
#     (321.73545578, 38.80185481, 0.07107543)>

# %%
print(f'There are {len(GCNS)} stars in GCNS')
# Out:
# There are 331312 variable stars in GCNS

# %% [markdown]
# #### Time Since Event Was Observed

# %%
t1 = Time.now()
dt = t1-t0

dt.to('year')
# Out:
# <Quantity 35.46336151 yr>

# %% [markdown]
# #### Ellipsoid Geometry

# %%
c = d0.to('lyr') / 2 # dist to foci from ellipse center (half the distance from Earth to SN1987A, the two foci)
a = (((dt.to('s') * const.c) / 2) + c).to('lyr') # semi-major axis of ellipse
# first term is the distance along the major axis beyond Earth -- it is half the distance light would travel in the time since the event was observed
     
print(a-c) # should be half the value of dt above, but in lyr
# Out:
# 17.73168075621652 lyr

# %% [markdown]
# #### GCNS Star Geometric Properties

# %%
d1 = (GCNS['dist']) # dist to GCNS stars

d2 = c1.separation_3d(c0) # dist from all GCNS stars to SN 1987A

# %%
# Q1. Has the star seen SN1987A yet?
SNYES = d2.to('lyr').value <= (d0.to('lyr') + (dt.to('s') * const.c)).to('lyr').value
SNNO = ~SNYES
# left side is the distance from the star to SN 1987A
# right side is the distance from SN 1987A to Earth plus the extra distance light has travelled since it was observed


# Q2. Is it within the SETI Ellipsoid?
EYES = (d1.to('lyr').value + d2.to('lyr').value) <= (2 * a.to('lyr').value)
ENO = ~EYES
# left side is distance from SN 1987A to star plus distance from star to Earth
# right side is the major axis (the sum of the two focal point distances for all points on an ellipse/ellipsoid is equal to the major axis length)

# Q3. Is it within some toleratnce of being ON the ellipse?
# Either a range of distance of time
tol = 0.1 # lyr
OYES = np.abs((d1.to('lyr').value + d2.to('lyr').value) - (2 * a.to('lyr').value)) <= tol
# check if sum of focal point distances minus the major axis diameter is within the interval (-tol, tol)

# %%
print('Total number of stars in GCNS:', len(d1))
print('Number of stars that have seen SN1987A:', np.sum(SNYES))
print('Number of stars that have not seen SN1987A:', np.sum(SNNO))
print('Number of stars within SETI Ellipsoid:', np.sum(EYES))
print('Number of stars within ' + str( tol ) + ' lyr of ellipsoid:', np.sum(OYES))
# Out:
# Total number of stars in GCNS: 331312
# Number of stars that have seen SN1987A: 192642
# Number of stars that have not seen SN1987A: 138670
# Number of stars within SETI Ellipsoid: 25952
# Number of stars within 0.1 lyr of ellipsoid: 136

# %%
print('Fraction of GCNS stars that have seen SN1987A:', np.sum(SNYES) / len(d1))
print('Fraction of GCNS stars that have not seen SN1987A:', np.sum(SNNO) / len(d1))
print('Fraction of GCNS stars within SETI Ellipsoid:', np.sum(EYES) / len(d1))
# Out:
# Fraction of GCNS stars that have seen SN1987A: 0.581451924469986
# Fraction of GCNS stars that have not seen SN1987A: 0.418548075530014
# Fraction of GCNS stars within SETI Ellipsoid: 0.07833099917902159

# %% [markdown]
# ## Plotting

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(GCNS['x'][SNNO], GCNS['y'][SNNO], GCNS['z'][SNNO], c='C3', s=1, alpha=0.05, rasterized=True)
ax.scatter(GCNS['x'][SNYES], GCNS['y'][SNYES], GCNS['z'][SNYES], c='C0', s=1, alpha=0.05, rasterized=True)
ax.scatter(GCNS['x'][EYES], GCNS['y'][EYES], GCNS['z'][EYES], c='C6', s=4, alpha=0.1, rasterized=True)
ax.scatter(GCNS['x'][OYES], GCNS['y'][OYES], GCNS['z'][OYES], c='k', s=20, alpha=0.95, rasterized=True)
ax.set_xlabel('X (pc)')
ax.set_ylabel('Y (pc)')
ax.set_zlabel('Z (pc)')
# Out:
# Text(0.5, 0, 'Z (pc)')

# %%
fig = plt.figure(figsize=(5,5), constrained_layout=True)
ax.remove()
ax = fig.add_subplot()

ax.scatter(GCNS['y'][SNNO], GCNS['z'][SNNO], c='C3', s=1, alpha=0.05, rasterized=True)
ax.scatter(GCNS['y'][SNYES], GCNS['z'][SNYES], c='C0', s=1, alpha=0.05, rasterized=True)
ax.scatter(GCNS['y'][EYES], GCNS['z'][EYES], c='C6', s=4, alpha=0.1, rasterized=True)
ax.scatter(GCNS['y'][OYES], GCNS['z'][OYES], c='k', s=20, alpha=0.95, rasterized=True)

ax.set_xlabel('Y (pc)')
ax.set_ylabel('Z (pc)')
# Out:
# Text(0, 0.5, 'Z (pc)')

# %% [markdown]
# ## Another way of looking at it in terms of time

# %%
# The ellipsoid is d2 + r = 2c + time (focal point distances equals major axis)
# So we can rewrite this as time = d2 + r - 2c

etime = d2.to('lyr') + d1.to('lyr') - (2*c)

x10 = np.abs(GCNS['x'].to('pc').value) < 10 # 'slice' through GCNS, with galactocentric |X| < 10 pc

# %%
print(f'There are {np.sum(x10)} stars in GCNS with galactocentric |X| less than 10 parsecs')
# Out:
# There are 47484 stars in GCNS with galactocentric |X| less than 10 parsecs

# %% [markdown]
# #### Plot the crossing time contours

# %%
H, xe, ye, bn = binned_statistic_2d(GCNS['y'][x10], GCNS['z'][x10],
                                    values = etime[x10].value + t0.decimalyear, 
                                    statistic='mean', bins=100) # mean binning for contours
XX, YY = np.meshgrid(xe, ye)


plt.figure(figsize=(8,8), constrained_layout=True)
plt.scatter(GCNS['y'][x10], GCNS['z'][x10],
            c=(etime[x10].value + t0.decimalyear), cmap=plt.cm.plasma, rasterized=True)
# contour (c) is the time (d2 + r - 2c) plus the time when the event was observed on Earth (1987)

cs = plt.contour(xe[1:], ye[1:], H.T, colors='w', linewidths=0.75) # binned contours
plt.clabel(cs, fontsize=12)



plt.xlabel('Y (pc)')
plt.ylabel('Z (pc)')
plt.xlim(-130, 130)
plt.ylim(-130,130)
plt.show()

# %%
plt.figure(figsize=(8,8))

plt.scatter(GCNS['y'][EYES], GCNS['z'][EYES], c='C6', s=4, alpha=0.5, rasterized=True)
plt.scatter(GCNS['y'][OYES], GCNS['z'][OYES], c='k', s=20, alpha=0.95, rasterized=True)

plt.xlabel('Y (pc)')
plt.ylabel('Z (pc)')
cs = plt.contour(xe[1:], ye[1:], H.T, colors='k', linewidths=0.75, levels=[1990, 2000, 2010, 2020, 2050, 2087])
plt.clabel(cs, fontsize=12)

plt.xlim(-80, 30)
plt.ylim(-80, 30)
plt.grid(True)

# %%
H, xe, ye, bn = binned_statistic_2d(GCNS['y'][x10], GCNS['z'][x10],
                                    values = etime[x10].value, statistic='mean', bins=100)
XX, YY = np.meshgrid(xe, ye)

plt.figure(figsize=(10,8))
plt.scatter(GCNS['y'][x10], GCNS['z'][x10],
            c=(etime[x10].value), cmap=plt.cm.plasma)
cb = plt.colorbar()
cb.set_label('$t - $'+format(t0.decimalyear, '7.4f') + ' (years)')

cs = plt.contour(xe[1:], ye[1:], H.T, colors='w', linewidths=0.75, levels=[10,35,100,300,500])
plt.clabel(cs, fontsize=12)


plt.xlabel('Y (pc)')
plt.ylabel('Z (pc)')
# Out:
# Text(0, 0.5, 'Z (pc)')
