# %%
import pandas as pd
from astropy.table import Table, QTable
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('..')
import ellipsoid

from astropy.time import Time
from astropy.coordinates import SkyCoord
from astropy import units as u

from astroquery.gaia import Gaia
import random

# %% [markdown]
# ### Read in photometry data from Open Astronomy Catalog
# #### API description at https://github.com/astrocatalogs/OACAPI

# %%
data = pd.read_csv('https://api.astrocats.space/SN1987A/photometry/time+band+magnitude?format=csv')
data = data.dropna()

# %%
photometry = Table.from_pandas(data)

# %%
vmask = photometry['band']=='V'

# %%
# Subtract MJD of February 23, 1987 (date of observation)
photometry['time'] = photometry['time']-46849

# %%
lc = photometry[vmask]

# %%
fig = plt.figure(figsize=[6,4], dpi=150)
plt.scatter(lc['time'], lc['magnitude'], s=1)
plt.ylim(18,2)
plt.title('SN 1987A Light Curve')
plt.xlabel('Days since Outburst')
plt.ylabel('Magnitude')
# Out:
# Text(0, 0.5, 'Magnitude')

# %% [markdown]
# #### Get a random light curve from the crossing list

# %%
file_name = '../Gaia_var_class'
c1, stars = ellipsoid.readFile(file_name)
tol = 0.1
start = 2014.569312182902

# %%
#Properties of SN1987A
t0 = Time({'year': 1987, 'month': 2, 'day': 23}, format='ymdhms')

c0_radec = SkyCoord.from_name('SN 1987A')

# Panagia (1999) https://ui.adsabs.harvard.edu/abs/1999IAUS..190..549P/abstract
d0 = 51.4 * u.kpc
d0_err = 1.2 * u.kpc

c0 = SkyCoord(ra=c0_radec.ra, dec=c0_radec.dec, distance=d0)

# %%
c1_x, stars_x = ellipsoid.crossErrorEllipsoid(c0, t0, c1, stars, tol)
print(f'{len(stars_x)} stars have crossed the ellipsoid during Gaia DR3 data collection time')
# Out:
# 217 stars have crossed the ellipsoid during Gaia DR3 data collection time

# %%
ids = stars_x['id']

# %%
merged_sf = '../GCNS_var_lc.xml'
lc_merged = QTable.read(merged_sf, format='votable')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1582347/3932572777.py in <module>
#       1 merged_sf = '../GCNS_var_lc.xml'
# ----> 2 lc_merged = QTable.read(merged_sf, format='votable')
#
# /mnt_home/anilipour/setiellipsoid/setienv/lib/python3.7/site-packages/astropy/table/connect.py in __call__(self, *args, **kwargs)
#      59         descriptions = kwargs.pop('descriptions', None)
#      60
# ---> 61         out = registry.read(cls, *args, **kwargs)
#      62
#      63         # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#
# /mnt_home/anilipour/setiellipsoid/setienv/lib/python3.7/site-packages/astropy/io/registry.py in read(cls, format, cache, *args, **kwargs)
#     525
#     526         reader = get_reader(format, cls)
# --> 527         data = reader(*args, **kwargs)
#     528
#     529         if not isinstance(data, cls):
#
# /mnt_home/anilipour/setiellipsoid/setienv/lib/python3.7/site-packages/astropy/io/votable/connect.py in read_table_votable(input, table_id, use_names_over_ids, verify, **kwargs)
#      84     """
#      85     if not isinstance(input, (VOTableFile, VOTable)):
# ---> 86         input = parse(input, table_id=table_id, verify=verify, **kwargs)
#      87
#      88     # Parse all table objects
#
# /mnt_home/anilipour/setiellipsoid/setienv/lib/python3.7/site-packages/astropy/utils/decorators.py in wrapper(*args, **kwargs)
#     534                     warnings.warn(message, warning_type, stacklevel=2)
#     535
# --> 536             return function(*args, **kwargs)
#     537
#     538         return wrapper
#
# /mnt_home/anilipour/setiellipsoid/setienv/lib/python3.7/site-packages/astropy/io/votable/table.py in parse(source, columns, invalid, verify, chunk_size, table_number, table_id, filename, unit_format, datatype_mapping, _debug_python_based_parser)
#     163     with iterparser.get_xml_iterator(
#     164             source,
# --> 165             _debug_python_based_parser=_debug_python_based_parser) as iterator:
#     166         return tree.VOTableFile(
#     167             config=config, pos=(1, 1)).parse(iterator, config)
#
# /opt/conda/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /mnt_home/anilipour/setiellipsoid/setienv/lib/python3.7/site-packages/astropy/utils/xml/iterparser.py in get_xml_iterator(source, _debug_python_based_parser)
#     158               event.
#     159     """
# --> 160     with _convert_to_fd_or_read_function(source) as fd:
#     161         if _debug_python_based_parser:
#     162             context = _slow_iterparse(fd)
#
# /opt/conda/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /mnt_home/anilipour/setiellipsoid/setienv/lib/python3.7/site-packages/astropy/utils/xml/iterparser.py in _convert_to_fd_or_read_function(fd)
#      61         return
#      62
# ---> 63     with data.get_readable_fileobj(fd, encoding='binary') as new_fd:
#      64         if sys.platform.startswith('win'):
#      65             yield new_fd.read
#
# /opt/conda/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /mnt_home/anilipour/setiellipsoid/setienv/lib/python3.7/site-packages/astropy/utils/data.py in get_readable_fileobj(name_or_obj, encoding, cache, show_progress, remote_timeout, sources, http_headers)
#     260                 timeout=remote_timeout, sources=sources,
#     261                 http_headers=http_headers)
# --> 262         fileobj = io.FileIO(name_or_obj, 'r')
#     263         if is_url and not cache:
#     264             delete_fds.append(fileobj)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../GCNS_var_lc.xml'

# %%
glcDict = {}
bplcDict = {}
rplcDict = {}

# %%
for sid in ids:
    glc, bplc, rplc = ellipsoid.getLC(lc_merged, sid, 'G'), ellipsoid.getLC(lc_merged, sid, 'BP'), ellipsoid.getLC(lc_merged, sid, 'RP')
    glcDict[str(sid)], bplcDict[str(sid)], rplcDict[str(sid)] = glc, bplc, rplc

# %%
lcChoice = random.choice(list(glcDict.keys()))

# %%
id_mask = stars_x['id'] == int(lcChoice)

# %%
ellipsoid.plotLC(str(lcChoice), c1_x[id_mask], stars_x[id_mask], glcDict, bplcDict, rplcDict, y='flux')

# %%
xtime = ellipsoid.xTime(c1_x[id_mask])[0]

# %%
lcDict = glcDict # choose g, bp, or rp light curve

lcTimes = Time(lcDict[lcChoice]['time'].value + 2455197.5, format='jd')
lcFlux = lcDict[lcChoice]['flux']
lcFerr = lcDict[lcChoice]['flux_error']
lcMag = lcDict[lcChoice]['mag']
# time offset described at https://gea.esac.esa.int/archive/documentation/GDR3/Gaia_archive/chap_datamodel/sec_dm_photometry/ssec_dm_epoch_photometry.html

# %% [markdown]
# #### Cross-correlation

# %%
# Add crossing time to supernova light curve times
lc['time'] = lc['time'] + xtime

# %%
# Add "normalized flux" column
lc['flux'] = (10**(-0.4*lc['magnitude']))/np.max(10**(-0.4*lc['magnitude']))/100 + 1

# %%
plt.figure(figsize=[10,3], dpi=150)

plt.vlines(xtime, ymin=min(lcFlux.value), ymax=max(lcFlux.value))
plt.scatter(lcTimes.value, lcFlux)
plt.scatter(lc['time'], lc['flux'])
plt.

# %%
from scipy.interpolate import interp1d

# %%
f = interp1d(lc['time'], lc['flux'])

# %%
rtimes = lcTimes.value >= xtime

# %%
plt.figure(figsize=[10,3], dpi=150)

plt.vlines(xtime, ymin=min(lcFlux.value), ymax=max(lcFlux.value))
plt.scatter(lcTimes.value, lcFlux)
plt.scatter(lcTimes.value[rtimes], f(lcTimes.value[rtimes]))

# %%
from scipy.signal import correlate

# %%
corrLC = correlate(lcFlux[rtimes], f(lcTimes.value[rtimes]), mode='same') / (len(lcFlux[rtimes])/2)

# %%
plt.figure(figsize=[10,3], dpi=150)

plt.vlines(xtime, ymin=min(lcFlux.value), ymax=max(lcFlux.value))
plt.scatter(lcTimes.value, lcFlux)
plt.scatter(lcTimes.value[rtimes], f(lcTimes.value[rtimes]))
plt.scatter(lcTimes.value[rtimes], corrLC)
